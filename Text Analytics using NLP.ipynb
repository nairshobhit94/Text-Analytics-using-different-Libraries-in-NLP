# %%
import nltk

# %% [markdown]
# # Tokenization of Sentence

# %%
from nltk.tokenize import sent_tokenize
text="""The Raisina Dialogue is a multilateral conference held annually in New Delhi. Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics. The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.
The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials. In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia. It is designed on the lines of Singapore's Shangri-La Dialogue.
The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['The Raisina Dialogue is a multilateral conference held annually in New Delhi.', 'Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics.', 'The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.', 'The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials.', 'In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia.', "It is designed on the lines of Singapore's Shangri-La Dialogue.", 'The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan']

# %% [markdown]
# # Toknization of Word

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', '.', 'Since', 'its', 'inception', 'in', '2016', ',', 'the', 'conference', 'has', 'emerged', 'as', 'India', '’', 's', 'flagship', 'conference', 'on', 'geopolitics', 'and', 'geo-economics', '.', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', ',', 'an', 'independent', 'think', 'tank', ',', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affairs', 'of', 'India', '.', 'The', 'conference', 'is', 'structured', 'as', 'a', 'multi-stakeholder', ',', 'cross-sectoral', 'discussion', ',', 'involving', 'a', 'variety', 'of', 'global', 'policymakers', 'including', 'heads', 'of', 'state', ',', 'cabinet', 'ministers', 'and', 'local', 'government', 'officials', '.', 'In', 'addition', ',', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', ',', 'as', 'well', 'as', 'members', 'of', 'the', 'media', 'a
# ...

# %% [markdown]
# # Frequency Distribution

# %%
from nltk.probability import FreqDist
fdist=FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 92 samples and 158 outcomes>

# %% [markdown]
# # Most Common Words

# %%
fdist.most_common(5)
# Out:
# [(',', 12), ('of', 9), ('the', 7), ('.', 6), ('as', 6)]

# %% [markdown]
# # Frequency Distribution Plot

# %%
import matplotlib.pyplot as plt
fdist.plot(50, cumulative=False)
plt.show()

# %% [markdown]
# # Stopwords

# %%
from nltk.corpus import stopwords
stop_words=(stopwords.words("english"))
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [markdown]
# # Remove Stopwords

# %%
filtered_sent=[]
for w in tokenized_word:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filtered Sentence",filtered_sent)
# Out:
# Tokenized Sentence: ['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', '.', 'Since', 'its', 'inception', 'in', '2016', ',', 'the', 'conference', 'has', 'emerged', 'as', 'India', '’', 's', 'flagship', 'conference', 'on', 'geopolitics', 'and', 'geo-economics', '.', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', ',', 'an', 'independent', 'think', 'tank', ',', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affairs', 'of', 'India', '.', 'The', 'conference', 'is', 'structured', 'as', 'a', 'multi-stakeholder', ',', 'cross-sectoral', 'discussion', ',', 'involving', 'a', 'variety', 'of', 'global', 'policymakers', 'including', 'heads', 'of', 'state', ',', 'cabinet', 'ministers', 'and', 'local', 'government', 'officials', '.', 'In', 'addition', ',', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', ',', 'as', 'well', 'as', 'members', 'of'
# ...

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['The', 'Raisina', 'Dialogue', 'multilateral', 'conference', 'held', 'annually', 'New', 'Delhi', '.', 'Since', 'inception', '2016', ',', 'conference', 'emerged', 'India', '’', 'flagship', 'conference', 'geopolitics', 'geo-economics', '.', 'The', 'conference', 'hosted', 'Observer', 'Research', 'Foundation', ',', 'independent', 'think', 'tank', ',', 'collaboration', 'Ministry', 'External', 'Affairs', 'India', '.', 'The', 'conference', 'structured', 'multi-stakeholder', ',', 'cross-sectoral', 'discussion', ',', 'involving', 'variety', 'global', 'policymakers', 'including', 'heads', 'state', ',', 'cabinet', 'ministers', 'local', 'government', 'officials', '.', 'In', 'addition', ',', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', ',', 'well', 'members', 'media', 'academia', '.', 'It', 'designed', 'lines', 'Singapore', "'s", 'Shangri-La', 'Dialogue', '.', 'The', 'name', '``', 'Raisina', 'Dialogue', "''", 'comes', 'Raisina', 'Hill', ','
# ...

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer=WordNetLemmatizer()

for word in filtered_sent:
    print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word, pos="v")))
# Out:
# The                 The
# Raisina             Raisina
# Dialogue            Dialogue
# multilateral        multilateral
# conference          conference
# held                hold
# annually            annually
# New                 New
# Delhi               Delhi
# .                   .
# Since               Since
# inception           inception
# 2016                2016
# ,                   ,
# conference          conference
# emerged             emerge
# India               India
# ’                   ’
# flagship            flagship
# conference          conference
# geopolitics         geopolitics
# geo-economics       geo-economics
# .                   .
# The                 The
# conference          conference
# hosted              host
# Observer            Observer
# Research            Research
# Foundation          Foundation
# ,                   ,
# independent         independent
# think               think
# tank                tank
# ,                   ,
# ...

# %% [markdown]
# # POS Tagging

# %%
nltk.pos_tag(filtered_sent)
# Out:
# [('The', 'DT'),
#  ('Raisina', 'NNP'),
#  ('Dialogue', 'NNP'),
#  ('multilateral', 'JJ'),
#  ('conference', 'NN'),
#  ('held', 'VBD'),
#  ('annually', 'RB'),
#  ('New', 'NNP'),
#  ('Delhi', 'NNP'),
#  ('.', '.'),
#  ('Since', 'IN'),
#  ('inception', 'NN'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('conference', 'NN'),
#  ('emerged', 'VBD'),
#  ('India', 'NNP'),
#  ('’', 'NNP'),
#  ('flagship', 'NN'),
#  ('conference', 'NN'),
#  ('geopolitics', 'NNS'),
#  ('geo-economics', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('conference', 'NN'),
#  ('hosted', 'VBD'),
#  ('Observer', 'NNP'),
#  ('Research', 'NNP'),
#  ('Foundation', 'NNP'),
#  (',', ','),
#  ('independent', 'JJ'),
#  ('think', 'NN'),
#  ('tank', 'NN'),
#  (',', ','),
#  ('collaboration', 'NN'),
#  ('Ministry', 'NNP'),
#  ('External', 'NNP'),
#  ('Affairs', 'NNP'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('conference', 'NN'),
#  ('structured', 'VBD'),
#  ('multi-stakeholder', 'NN'),
#  (',', ','),
# ...

# %% [markdown]
# # Text Classification using spacy library

# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# %% [markdown]
# # Sentence Detection

# %%
text="""The Raisina Dialogue is a multilateral conference held annually in New Delhi. Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics. The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.
The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials. In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia. It is designed on the lines of Singapore's Shangri-La Dialogue.
The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan"""
about_doc=nlp(text)
sentences=list(about_doc.sents)
len(sentences)
# Out:
# 7

# %%
for sentence in sentences:
    print(sentence)
# Out:
# The Raisina Dialogue is a multilateral conference held annually in New Delhi.
# Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics.
# The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.
#
# The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials.
# In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia.
# It is designed on the lines of Singapore's Shangri-La Dialogue.
#
# The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan

# %% [markdown]
# # Tokenization using Spacy library

# %%
for token in about_doc:
    print(token, token.idx)
# Out:
# The 0
# Raisina 4
# Dialogue 12
# is 21
# a 24
# multilateral 26
# conference 39
# held 50
# annually 55
# in 64
# New 67
# Delhi 71
# . 76
# Since 78
# its 84
# inception 88
# in 98
# 2016 101
# , 105
# the 107
# conference 111
# has 122
# emerged 126
# as 134
# India 137
# ’s 142
# flagship 145
# conference 154
# on 165
# geopolitics 168
# and 180
# geo 184
# - 187
# economics 188
# . 197
# The 199
# conference 203
# is 214
# hosted 217
# by 224
# the 227
# Observer 231
# Research 240
# Foundation 249
# , 259
# an 261
# independent 264
# think 276
# tank 282
# , 286
# in 288
# collaboration 291
# with 305
# the 310
# Ministry 314
# of 323
# External 326
# Affairs 335
# of 343
# India 346
# . 351
#
#  352
# The 353
# conference 357
# is 368
# structured 371
# as 382
# a 385
# multi 387
# - 392
# stakeholder 393
# , 404
# cross 406
# - 411
# sectoral 412
# discussion 421
# , 431
# involving 433
# a 443
# variety 445
# of 453
# global 456
# policymakers 463
# including 476
# ...

# %% [markdown]
# # Another way of tokenization

# %%
for token in about_doc:
    print(token, token.idx, token.text_with_ws, 
         token.is_alpha, token.is_punct, token.is_space,
         token.shape_, token.is_stop)
# Out:
# The 0 The  True False False Xxx True
# Raisina 4 Raisina  True False False Xxxxx False
# Dialogue 12 Dialogue  True False False Xxxxx False
# is 21 is  True False False xx True
# a 24 a  True False False x True
# multilateral 26 multilateral  True False False xxxx False
# conference 39 conference  True False False xxxx False
# held 50 held  True False False xxxx False
# annually 55 annually  True False False xxxx False
# in 64 in  True False False xx True
# New 67 New  True False False Xxx False
# Delhi 71 Delhi True False False Xxxxx False
# . 76 .  False True False . False
# Since 78 Since  True False False Xxxxx True
# its 84 its  True False False xxx True
# inception 88 inception  True False False xxxx False
# in 98 in  True False False xx True
# 2016 101 2016 False False False dddd False
# , 105 ,  False True False , False
# the 107 the  True False False xxx True
# conference 111 conference  True False False xxxx False
# has 122 has  True False False xxx True
# ...

# %% [markdown]
# # Best way of tokenizing the whole article.

# %%
import re
import spacy
from spacy.tokenizer import Tokenizer
text_nlp=spacy.load("en_core_web_sm")
prefixes_re=spacy.util.compile_prefix_regex(text_nlp.Defaults.prefixes)
suffixes_re=spacy.util.compile_suffix_regex(text_nlp.Defaults.suffixes)
infix_re=re.compile(r'''[-~]''')

def text_tokenizer(nlp):
    return Tokenizer(nlp.vocab, prefix_search=prefixes_re.search,
                    suffix_search=suffixes_re.search,
                    infix_finditer=infix_re.finditer,
                    token_match=None)

text_nlp.tokenizer=text_tokenizer(text_nlp)
text_nlp_tokenizer_doc=text_nlp(text)
print([token.text for token in text_nlp_tokenizer_doc])
# Out:
# ['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', '.', 'Since', 'its', 'inception', 'in', '2016', ',', 'the', 'conference', 'has', 'emerged', 'as', 'India', '’s', 'flagship', 'conference', 'on', 'geopolitics', 'and', 'geo', '-', 'economics', '.', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', ',', 'an', 'independent', 'think', 'tank', ',', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affairs', 'of', 'India', '.', '\n', 'The', 'conference', 'is', 'structured', 'as', 'a', 'multi', '-', 'stakeholder', ',', 'cross', '-', 'sectoral', 'discussion', ',', 'involving', 'a', 'variety', 'of', 'global', 'policymakers', 'including', 'heads', 'of', 'state', ',', 'cabinet', 'ministers', 'and', 'local', 'government', 'officials', '.', 'In', 'addition', ',', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', ',', 'as', 'well', 'as', 'members'
# ...

# %% [markdown]
# # Removing stopwords using Spacy

# %%
import spacy
spacy_stopwords=spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stopwords)
# Out:
# 326

# %% [markdown]
# # Print all the stop words

# %%
print(spacy_stopwords)
# Out:
# {'ever', 'twelve', 'while', 'not', 'itself', 'anyone', 'hence', 'my', 'neither', 'thence', 'under', 'n‘t', 'a', 'behind', '’d', 'formerly', 'others', 'whoever', "'d", 'rather', 'go', 'thru', 'otherwise', 'thereafter', 'will', 'whose', 'have', 'became', 'make', 'say', 'sometimes', 'his', 'else', 'ours', 'nevertheless', 'this', 'towards', 'were', 'before', 'herself', 'call', 'most', 'yourselves', 'least', 'everything', 'however', 'another', 'because', 'five', 'serious', 'same', 'six', 'therefore', 'would', 'alone', 'anyhow', 'except', 'below', 'three', 'top', 'mine', 'see', 'here', 'several', 'whereby', 'but', 'besides', 'their', 'used', 'give', 'where', 'throughout', 'during', 'using', 'was', 'therein', 'if', "n't", 'above', 'perhaps', 'enough', 'him', 'these', 'an', 'yet', 'after', 'further', 'becoming', 'into', 'nothing', 'every', 'myself', 'they', 'without', 'almost', 'afterwards', 'regarding', 'beyond', 'moreover', 'become', 'due', 'whom', 'also', 'well', 'you', 'beside', 'four', 
# ...

# %% [markdown]
# # Removing stopwords from text

# %%
for stopword in about_doc:
    if not stopword.is_stop:
        print(stopword)
# Out:
# Raisina
# Dialogue
# multilateral
# conference
# held
# annually
# New
# Delhi
# .
# inception
# 2016
# ,
# conference
# emerged
# India
# ’s
# flagship
# conference
# geopolitics
# geo
# -
# economics
# .
# conference
# hosted
# Observer
# Research
# Foundation
# ,
# independent
# think
# tank
# ,
# collaboration
# Ministry
# External
# Affairs
# India
# .
#
#
# conference
# structured
# multi
# -
# stakeholder
# ,
# cross
# -
# sectoral
# discussion
# ,
# involving
# variety
# global
# policymakers
# including
# heads
# state
# ,
# cabinet
# ministers
# local
# government
# officials
# .
# addition
# ,
# Dialogue
# welcomes
# major
# private
# sector
# executives
# ,
# members
# media
# academia
# .
# designed
# lines
# Singapore
# Shangri
# -
# La
# Dialogue
# .
#
#
# "
# Raisina
# Dialogue
# "
# comes
# Raisina
# Hill
# ,
# elevation
# New
# Delhi
# ,
# seat
# Government
# India
# ,
# Presidential
# Palace
# India
# ,
# Rashtrapati
# Bhavan

# %% [markdown]
# # Creating a list of tokens for not having stopwords

# %%
not_having_stopword_doc=[stopword for stopword in about_doc if not stopword.is_stop]
print(not_having_stopword_doc)
# Out:
# [Raisina, Dialogue, multilateral, conference, held, annually, New, Delhi, ., inception, 2016, ,, conference, emerged, India, ’s, flagship, conference, geopolitics, geo, -, economics, ., conference, hosted, Observer, Research, Foundation, ,, independent, think, tank, ,, collaboration, Ministry, External, Affairs, India, .,
# , conference, structured, multi, -, stakeholder, ,, cross, -, sectoral, discussion, ,, involving, variety, global, policymakers, including, heads, state, ,, cabinet, ministers, local, government, officials, ., addition, ,, Dialogue, welcomes, major, private, sector, executives, ,, members, media, academia, ., designed, lines, Singapore, Shangri, -, La, Dialogue, .,
# , ", Raisina, Dialogue, ", comes, Raisina, Hill, ,, elevation, New, Delhi, ,, seat, Government, India, ,, Presidential, Palace, India, ,, Rashtrapati, Bhavan]

# %% [markdown]
# # Lemmatization using Spacy

# %%
for lemmatize in about_doc:
    print(lemmatize, lemmatize.lemma_)
# Out:
# The the
# Raisina Raisina
# Dialogue Dialogue
# is be
# a a
# multilateral multilateral
# conference conference
# held hold
# annually annually
# in in
# New New
# Delhi Delhi
# . .
# Since since
# its -PRON-
# inception inception
# in in
# 2016 2016
# , ,
# the the
# conference conference
# has have
# emerged emerge
# as as
# India India
# ’s ’s
# flagship flagship
# conference conference
# on on
# geopolitics geopolitic
# and and
# geo geo
# - -
# economics economic
# . .
# The the
# conference conference
# is be
# hosted host
# by by
# the the
# Observer Observer
# Research Research
# Foundation Foundation
# , ,
# an an
# independent independent
# think think
# tank tank
# , ,
# in in
# collaboration collaboration
# with with
# the the
# Ministry Ministry
# of of
# External External
# Affairs Affairs
# of of
# India India
# . .
#
#
#
# The the
# conference conference
# is be
# structured structure
# as as
# a a
# multi multi
# - -
# stakeholder stakeholder
# , ,
# cross cross
# ...

# %% [markdown]
# # POS Tagging

# %%
for token in about_doc:
    print(token, token.tag_ , token.pos_, spacy.explain(token.tag_))
# Out:
# The DT DET determiner
# Raisina NNP PROPN noun, proper singular
# Dialogue NNP PROPN noun, proper singular
# is VBZ VERB verb, 3rd person singular present
# a DT DET determiner
# multilateral JJ ADJ adjective
# conference NN NOUN noun, singular or mass
# held VBN VERB verb, past participle
# annually RB ADV adverb
# in IN ADP conjunction, subordinating or preposition
# New NNP PROPN noun, proper singular
# Delhi NNP PROPN noun, proper singular
# . . PUNCT punctuation mark, sentence closer
# Since IN ADP conjunction, subordinating or preposition
# its PRP$ DET pronoun, possessive
# inception NN NOUN noun, singular or mass
# in IN ADP conjunction, subordinating or preposition
# 2016 CD NUM cardinal number
# , , PUNCT punctuation mark, comma
# the DT DET determiner
# conference NN NOUN noun, singular or mass
# has VBZ VERB verb, 3rd person singular present
# emerged VBN VERB verb, past participle
# as IN ADP conjunction, subordinating or preposition
# ...

# %% [markdown]
# # Using POS to extract particular category of words

# %%
nouns=[]
adjectives=[]
for token in about_doc:
    if token.pos_=="NOUN":
        nouns.append(token)
    if token.pos_=="ADJ":
        adjectives.append(token)
        
        
print(nouns)
print(adjectives)
# Out:
# [conference, inception, conference, flagship, conference, geopolitics, economics, conference, think, tank, collaboration, conference, discussion, variety, policymakers, heads, state, cabinet, ministers, government, officials, addition, sector, executives, members, media, academia, lines, name, elevation, seat]
# [multilateral, independent, multi, -, stakeholder, cross, -, sectoral, global, local, major, private]

# %% [markdown]
# # Visualisation using displacy

# %%
from spacy import displacy
displacy.render(about_doc, style="ent", jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     The Raisina Dialogue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a multilateral conference held annually in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Since its inception in
# ...

# %% [markdown]
# # Different techniques using Visualisation in Spacy

# %%
displacy.render(about_doc, style="dep", jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b735dc901e664e62a8649bf31a9fcda5-0" class="displacy" width="25075" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Raisina</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Dialogue</tspan>
# ...

# %% [markdown]
# # Text Classification using TextBlob

# %%
from textblob import TextBlob
text="""The Raisina Dialogue is a multilateral conference held annually in New Delhi. Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics. The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.
The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials. In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia. It is designed on the lines of Singapore's Shangri-La Dialogue.
The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan"""
text_blob=TextBlob(text)

# %% [markdown]
# # Tokenizing the whole article

# %%
text_blob.sentences
# Out:
# [Sentence("The Raisina Dialogue is a multilateral conference held annually in New Delhi."),
#  Sentence("Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics."),
#  Sentence("The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India."),
#  Sentence("The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials."),
#  Sentence("In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia."),
#  Sentence("It is designed on the lines of Singapore's Shangri-La Dialogue."),
# ...

# %% [markdown]
# # Another way of tokenizing the whole article

# %%
text_blob.words
# Out:
# WordList(['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', 'Since', 'its', 'inception', 'in', '2016', 'the', 'conference', 'has', 'emerged', 'as', 'India', '’', 's', 'flagship', 'conference', 'on', 'geopolitics', 'and', 'geo-economics', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', 'an', 'independent', 'think', 'tank', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affairs', 'of', 'India', 'The', 'conference', 'is', 'structured', 'as', 'a', 'multi-stakeholder', 'cross-sectoral', 'discussion', 'involving', 'a', 'variety', 'of', 'global', 'policymakers', 'including', 'heads', 'of', 'state', 'cabinet', 'ministers', 'and', 'local', 'government', 'officials', 'In', 'addition', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', 'as', 'well', 'as', 'members', 'of', 'the', 'media', 'and', 'academia', 'It', 'is', 'designed', 'on', 'the
# ...

# %% [markdown]
# # Lemmatization the whole article

# %%
text_blob=TextBlob(text)
from textblob import Word
w=Word(text_blob)
w.lemmatize()
# Out:
# TextBlob("The Raisina Dialogue is a multilateral conference held annually in New Delhi. Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics. The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India.
# The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials. In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia. It is designed on the lines of Singapore's Shangri-La Dialogue.
# The name "Raisina Dialogue" comes from Raisina Hill, an elevation in New Delhi, seat of the Government of India, as well as the Presidential Palace of India, Rashtrapati Bhavan")

# %% [markdown]
# # Word Inflection

# %%
text_blob.words
# Out:
# WordList(['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', 'Since', 'its', 'inception', 'in', '2016', 'the', 'conference', 'has', 'emerged', 'as', 'India', '’', 's', 'flagship', 'conference', 'on', 'geopolitics', 'and', 'geo-economics', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', 'an', 'independent', 'think', 'tank', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affairs', 'of', 'India', 'The', 'conference', 'is', 'structured', 'as', 'a', 'multi-stakeholder', 'cross-sectoral', 'discussion', 'involving', 'a', 'variety', 'of', 'global', 'policymakers', 'including', 'heads', 'of', 'state', 'cabinet', 'ministers', 'and', 'local', 'government', 'officials', 'In', 'addition', 'The', 'Dialogue', 'also', 'welcomes', 'major', 'private', 'sector', 'executives', 'as', 'well', 'as', 'members', 'of', 'the', 'media', 'and', 'academia', 'It', 'is', 'designed', 'on', 'the
# ...

# %%
text_blob.words.singularize()
# Out:
# WordList(['The', 'Raisina', 'Dialogue', 'is', 'a', 'multilateral', 'conference', 'held', 'annually', 'in', 'New', 'Delhi', 'Since', 'it', 'inception', 'in', '2016', 'the', 'conference', 'ha', 'emerged', 'a', 'Indium', '’', 's', 'flagship', 'conference', 'on', 'geopolitic', 'and', 'geo-economic', 'The', 'conference', 'is', 'hosted', 'by', 'the', 'Observer', 'Research', 'Foundation', 'an', 'independent', 'think', 'tank', 'in', 'collaboration', 'with', 'the', 'Ministry', 'of', 'External', 'Affair', 'of', 'Indium', 'The', 'conference', 'is', 'structured', 'a', 'a', 'multi-stakeholder', 'cross-sectoral', 'discussion', 'involving', 'a', 'variety', 'of', 'global', 'policymaker', 'including', 'head', 'of', 'state', 'cabinet', 'minister', 'and', 'local', 'government', 'official', 'In', 'addition', 'The', 'Dialogue', 'also', 'welcome', 'major', 'private', 'sector', 'executive', 'a', 'well', 'a', 'member', 'of', 'the', 'medium', 'and', 'academium', 'It', 'is', 'designed', 'on', 'the', 'line', '
# ...

# %% [markdown]
# # Checking the Sentiment Polarity

# %%
text_blob.sentiment
# Out:
# Sentiment(polarity=0.04835858585858585, subjectivity=0.24545454545454545)

# %% [markdown]
# # POS Tagging

# %%
text_blob.tags
# Out:
# [('The', 'DT'),
#  ('Raisina', 'NNP'),
#  ('Dialogue', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('multilateral', 'JJ'),
#  ('conference', 'NN'),
#  ('held', 'VBD'),
#  ('annually', 'RB'),
#  ('in', 'IN'),
#  ('New', 'NNP'),
#  ('Delhi', 'NNP'),
#  ('Since', 'IN'),
#  ('its', 'PRP$'),
#  ('inception', 'NN'),
#  ('in', 'IN'),
#  ('2016', 'CD'),
#  ('the', 'DT'),
#  ('conference', 'NN'),
#  ('has', 'VBZ'),
#  ('emerged', 'VBN'),
#  ('as', 'IN'),
#  ('India', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('flagship', 'JJ'),
#  ('conference', 'NN'),
#  ('on', 'IN'),
#  ('geopolitics', 'NNS'),
#  ('and', 'CC'),
#  ('geo-economics', 'NNS'),
#  ('The', 'DT'),
#  ('conference', 'NN'),
#  ('is', 'VBZ'),
#  ('hosted', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Observer', 'NNP'),
#  ('Research', 'NNP'),
#  ('Foundation', 'NNP'),
#  ('an', 'DT'),
#  ('independent', 'JJ'),
#  ('think', 'NN'),
#  ('tank', 'NN'),
#  ('in', 'IN'),
#  ('collaboration', 'NN'),
#  ('with', 'IN'),
# ...

# %% [markdown]
# # Noun_Extraction

# %%
text_blob.noun_phrases
# Out:
# WordList(['raisina dialogue', 'multilateral conference', 'delhi', 'india', '’ s flagship conference', 'observer', 'research foundation', 'ministry', 'india', 'cross-sectoral discussion', 'global policymakers', 'cabinet ministers', 'local government officials', 'dialogue', 'major private sector executives', 'singapore', 'shangri-la dialogue', 'raisina dialogue', 'raisina', 'delhi', 'india', 'presidential palace', 'india', 'rashtrapati bhavan'])

# %% [markdown]
# # Counting the n-grams

# %%
text_blob.ngrams(n=4)
# Out:
# [WordList(['The', 'Raisina', 'Dialogue', 'is']),
#  WordList(['Raisina', 'Dialogue', 'is', 'a']),
#  WordList(['Dialogue', 'is', 'a', 'multilateral']),
#  WordList(['is', 'a', 'multilateral', 'conference']),
#  WordList(['a', 'multilateral', 'conference', 'held']),
#  WordList(['multilateral', 'conference', 'held', 'annually']),
#  WordList(['conference', 'held', 'annually', 'in']),
#  WordList(['held', 'annually', 'in', 'New']),
#  WordList(['annually', 'in', 'New', 'Delhi']),
#  WordList(['in', 'New', 'Delhi', 'Since']),
#  WordList(['New', 'Delhi', 'Since', 'its']),
#  WordList(['Delhi', 'Since', 'its', 'inception']),
#  WordList(['Since', 'its', 'inception', 'in']),
#  WordList(['its', 'inception', 'in', '2016']),
#  WordList(['inception', 'in', '2016', 'the']),
#  WordList(['in', '2016', 'the', 'conference']),
#  WordList(['2016', 'the', 'conference', 'has']),
#  WordList(['the', 'conference', 'has', 'emerged']),
#  WordList(['conference', 'has', 'emerged', 'as']),
# ...

# %% [markdown]
# # Translating the whole article to Hindi

# %%
text_blob.sentences
# Out:
# [Sentence("The Raisina Dialogue is a multilateral conference held annually in New Delhi."),
#  Sentence("Since its inception in 2016, the conference has emerged as India’s flagship conference on geopolitics and geo-economics."),
#  Sentence("The conference is hosted by the Observer Research Foundation, an independent think tank, in collaboration with the Ministry of External Affairs of India."),
#  Sentence("The conference is structured as a multi-stakeholder, cross-sectoral discussion, involving a variety of global policymakers including heads of state, cabinet ministers and local government officials."),
#  Sentence("In addition, The Dialogue also welcomes major private sector executives, as well as members of the media and academia."),
#  Sentence("It is designed on the lines of Singapore's Shangri-La Dialogue."),
# ...

# %%
text_blob.translate(to="hi")
# Out:
# TextBlob("रायसीना संवाद एक बहुपक्षीय सम्मेलन है जिसका आयोजन नई दिल्ली में प्रतिवर्ष किया जाता है। 2016 में अपनी स्थापना के बाद से, यह सम्मेलन भारत के भू-राजनीति और भू-अर्थशास्त्र पर प्रमुख सम्मेलन के रूप में उभरा है। इस सम्मेलन की मेजबानी ऑब्जर्वर रिसर्च फाउंडेशन, भारत के विदेश मंत्रालय के सहयोग से एक स्वतंत्र थिंक टैंक द्वारा की जाती है।
# सम्मेलन को बहु-हितधारक, क्रॉस-सेक्टोरल चर्चा के रूप में संरचित किया गया है, जिसमें विभिन्न वैश्विक नीति-निर्माता शामिल हैं, जिनमें राज्य के प्रमुख, कैबिनेट मंत्री और स्थानीय सरकारी अधिकारी शामिल हैं। इसके अलावा, संवाद मुख्य निजी क्षेत्र के अधिकारियों के साथ-साथ मीडिया और शिक्षाविदों के सदस्यों का भी स्वागत करता है। इसे सिंगापुर के शांगरी-ला डायलॉग की तर्ज पर बनाया गया है।
# "रायसीना डायलॉग" नाम रायसीना हिल से आया है, जो नई दिल्ली में एक ऊँचाई है, भारत सरकार की सीट है, साथ ही साथ भारत का राष्ट्रपति भवन, राष्ट्रपति भवन भी है।")
